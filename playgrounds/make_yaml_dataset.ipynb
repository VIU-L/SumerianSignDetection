# %%
# transforms current dataset structure to YOLO format
import os
import shutil
import json
ROOT_DIR = "../"
OUTPUT_DIR = "../3_YOLO_ultra/dataset/"

# %%
# current structure :
# ROOT_DIR/HeiCuBeDa/Images_MSII_Filter/  --> images
# MaiCuBeDa/train_photo_anno.json  --> annotations (train)
# MaiCuBeDa/test_photo_anno.json --> annotations (val)

# content in json:
# {
#     "HS_1220_03": {
#         "tablet_ID": "HS_1220",
#         "side": "front",
#         "image_path": "../HeiCuBeDa/Images_MSII_Filter/HS_1220_HeiCuBeDa_GMOCF_r1.50_n4_v512_03_front.png",
#         "bboxes": [
#             {
#                 "bbox": [
#                     13,
#                     17,
#                     121,
#                     122
#                 ],
#                 "charname": "U",
#                 "transliteration": "1(u)",
#                 "charname_id": 17,
#                 "transliteration_id": 21
#             },
#             {
#                 "bbox": [
#                     11,
#                     159,
#                     111,
#                     293
#                 ],
#                 "charname": "KI",
#                 "transliteration": "ki",
#                 "charname_id": 3,
#                 "transliteration_id": 3
#             },...

# %%
# required YOLO format:
# OUTPUT_DIR/images/train/  --> images for training
# OUTPUT_DIR/images/val/    --> images for validation
# OUTPUT_DIR/labels/train/  --> labels for training
# OUTPUT_DIR/labels/val/    --> labels for validation
# where label files are .txt files with same name as images, each line in txt file:
# <class_id> <x_center> <y_center> <width> <height>
# all values are normalized (divided by image width and height)

# %%
# existing files
TRAIN_JSON = os.path.join(ROOT_DIR, "MaiCuBeDa/train_photo_anno.json")
VAL_JSON   = os.path.join(ROOT_DIR, "MaiCuBeDa/test_photo_anno.json")
IMAGES_DIR = os.path.join(ROOT_DIR, "HeiCuBeDa/Images_MSII_Filter/")

# choose task
label_key = "unicode_topN" # "is_sign" / "charname" / "transliteration" / "charname_topN" / "unicode" / "unicode_topN"
N=150
if label_key != "is_sign":
    OUTPUT_DIR = OUTPUT_DIR[:-1] + f"_{label_key}"

# target YOLO folders
IMG_TRAIN_DIR = os.path.join(OUTPUT_DIR, "images/train")
IMG_VAL_DIR   = os.path.join(OUTPUT_DIR, "images/val")
LBL_TRAIN_DIR = os.path.join(OUTPUT_DIR, "labels/train")
LBL_VAL_DIR   = os.path.join(OUTPUT_DIR, "labels/val")
os.makedirs(IMG_TRAIN_DIR, exist_ok=True)
os.makedirs(IMG_VAL_DIR, exist_ok=True)
os.makedirs(LBL_TRAIN_DIR, exist_ok=True)
os.makedirs(LBL_VAL_DIR, exist_ok=True)

# %%
import re
if label_key == "charname" or label_key == "charname_topN":
    with open(os.path.join(ROOT_DIR, "MaiCuBeDa/charname_to_id.json"),"r",encoding="utf-8") as f:
        dict_id = json.load(f)
    if label_key == "charname_topN":
        for k,v in dict_id.items():
            if v >= N:
                dict_id[k] = N  # group together
        # save modified dict
        with open(os.path.join(ROOT_DIR, f"MaiCuBeDa/charname_to_id_top{N}.json"),"w",encoding="utf-8") as f:
            json.dump(dict_id, f, ensure_ascii=False, indent=4)
elif label_key == "transliteration":
    with open(os.path.join(ROOT_DIR, "MaiCuBeDa/transliteration_to_id.json"),"r",encoding="utf-8") as f:
        dict_id = json.load(f)

elif label_key == "unicode" or label_key == "unicode_topN":
    with open(os.path.join(ROOT_DIR, "MaiCuBeDa/unicode_to_id.json"),"r",encoding="utf-8") as f:
        dict_id = json.load(f)
        
reverse_dict_id = {v:k for k,v in dict_id.items()}
if label_key == "charname_topN":
    reverse_dict_id[N] = "OTHER"

# %%
reverse_dict_id
# Out:
# {0: '𒀭',
#  1: '𒀀',
#  2: '𒁀',
#  3: '𒆠',
#  4: '𒁹',
#  5: '𒈬',
#  6: '𒉌',
#  7: '𒈾',
#  8: '𒈠',
#  9: '𒈗',
#  10: '𒋗',
#  11: '𒌨',
#  12: '𒋫',
#  13: '𒌗',
#  14: '𒌓',
#  15: '𒑘',
#  16: '𒂵',
#  17: '𒌋',
#  18: '𒁕',
#  19: '𒇽',
#  20: '𒀸',
#  21: '𒁉',
#  22: '𒅆',
#  23: '𒂠',
#  24: '𒉈',
#  25: '𒌉',
#  26: '𒂆',
#  27: '𒂗',
#  28: '𒑁',
#  29: '𒄑',
#  30: '𒆬',
#  31: '𒋾',
#  32: '𒇲',
#  33: '𒄿',
#  34: '𒈨',
#  35: '𒃻',
#  36: '𒊮',
#  37: '𒍑',
#  38: '𒂍',
#  39: '𒆷',
#  40: '<OTHER>',
#  41: '𒇻',
#  42: '𒍣',
#  43: '𒊏',
#  44: '𒌆',
#  45: '𒐉',
#  46: '𒆤',
#  47: '𒊭',
#  48: '𒌝',
#  49: '𒂊',
#  50: '𒐊',
#  51: '𒄭',
#  52: '𒁺',
#  53: '𒌋𒌋',
#  54: '𒄥',
#  55: '𒄞',
#  56: '𒉡',
#  57: '𒊩𒌆',
#  58: '𒐀',
#  59: '𒋡',
#  60: '𒈧',
#  61: '𒆪',
#  62: '𒐈',
#  63: '𒃲',
#  64: '𒌑',
#  65: '𒅇',
#  66: '𒄨',
#  67: '𒋛',
#  68: '𒀉',
#  69: '𒀊',
#  70: '𒈦',
#  71: '𒊑',
#  72: '𒅗',
#  73: '𒅎',
#  74: '𒍝',
#  75: '𒆗',
#  76: '𒌍',
#  77: '𒊷',
#  78: '𒅔',
#  79: '𒊕',
#  80: '𒃷',
#  81: '𒉺',
#  82: '𒄀',
#  83: '𒊓',
#  84: '𒈝',
#  85: '𒆕',
#  86: '𒈣',
#  87: '𒊬',
#  88: '𒂗𒍪',
#  89: '𒈹',
#  90: '𒋗𒃸',
#  91: '𒀳',
#  92: '𒈤',
#  93: '𒁍',
#  94: '𒍪',
#  95: '𒅅',
#  96: '𒋢',
#  97: '𒈪',
#  98: '𒐏',
#  99: '𒐌',
#  100: '𒌈',
#  101: '𒄩',
#  102: '𒂷',
#  103: '𒑄',
#  104: '𒑖',
#  105: '𒇷',
#  106: '𒉿',
#  107: '𒀠',
#  108: '𒐕',
#  109: '𒌓𒁺',
#  110: '𒃶',
#  111: '𒂡',
#  112: '𒐃',
#  113: '𒃮',
#  114: '𒁮',
#  115: '𒌅',
#  116: '𒊒',
#  117: '𒑌',
#  118: '𒋻',
#  119: '𒑑',
#  120: '𒄘',
#  121: '𒃢',
#  122: '𒅁',
#  123: '𒋧',
#  124: '𒋀',
#  125: '𒄖',
#  126: '𒑏',
#  127: '𒄷',
#  128: '𒄯',
#  129: '𒋽',
#  130: '𒀜',
#  131: '𒂄',
#  132: '𒆥',
#  133: '𒄄',
#  134: '𒑐',
#  135: '𒀀𒀭',
#  136: '𒄊',
#  137: '𒀝',
#  138: '𒑒',
#  139: '𒁾',
#  140: '𒄠',
#  141: '𒅖',
#  142: '𒁇',
#  143: '𒐁',
#  144: '𒁲',
#  145: '𒉆',
#  146: '𒈥',
#  147: '𒀫',
#  148: '𒑚',
#  149: '𒑛',
#  150: '𒋞',
#  151: '𒅆𒌨',
#  152: '𒍥',
#  153: '𒐐',
#  154: '𒅕',
#  155: '𒁁',
#  156: '𒇯',
#  157: '𒅥',
#  158: '𒋆',
#  159: '𒉣',
#  160: '𒋓',
#  161: '𒌦',
#  162: '𒆰',
#  163: '𒂼',
#  164: '𒊩',
#  165: '𒌷',
#  166: '𒐖',
#  167: '𒅆𒊒',
#  168: '𒋃',
#  169: '𒋀𒆠',
#  170: '𒈜',
#  171: '𒌌',
#  172: '𒀾',
#  173: '𒐚',
#  174: '𒂟',
#  175: '𒆸',
#  176: '𒍏',
#  177: '𒐄',
#  178: '𒐎',
#  179: '𒋩',
#  180: '𒉏',
#  181: '𒍠',
#  182: '𒀖',
#  183: '𒁴',
#  184: '𒋀𒀊',
#  185: '𒑗',
#  186: '𒉌𒌓',
#  187: '𒌫',
#  188: '𒑜',
#  189: '𒅆𒂟',
#  190: '𒁄',
#  191: '𒋼𒀊',
#  192: '𒊩𒆳',
#  193: '𒊹',
#  194: '𒌇',
#  195: '𒁶',
#  196: '𒃼',
#  197: '𒐅',
#  198: '𒅈',
#  199: '𒅍',
#  200: '𒁯',
#  201: '𒋼',
#  202: '𒌀',
#  203: '𒑔',
#  204: '𒀵',
#  205: '𒅤𒊭',
#  206: '𒉻',
#  207: '𒀀𒇉',
#  208: '𒌋𒌓𒆤',
#  209: '𒉽',
#  210: '𒀴',
#  211: '𒐟',
#  212: '𒉺𒇻',
#  213: '𒌒',
#  214: '𒍩𒀀𒀭',
#  215: '𒋰',
#  216: '𒄈',
#  217: '𒐗',
#  218: '𒀕',
#  219: '𒉘',
#  220: '𒐞',
#  221: '𒁈',
#  222: '𒐘',
#  223: '𒉺𒁽',
#  224: '𒍩',
#  225: '𒂠𒑘',
#  226: '𒁹𒁹𒁹',
#  227: '𒍪𒀊',
#  228: '𒂖',
#  229: '𒆳',
#  230: '𒄴',
#  231: '𒂁',
#  232: '𒋛𒀀',
#  233: '𒋳',
#  234: '𒈛',
#  235: '𒈩',
#  236: '𒋼𒀀',
#  237: '𒂗𒆤',
#  238: '𒐙',
#  239: '𒄫',
#  240: '𒃡',
#  241: '𒅤',
#  242: '𒀲',
#  243: '𒄉',
#  244: '𒀀𒋢',
#  245: '𒋚',
#  246: '𒐜',
#  247: '𒋜',
#  248: '𒍮',
#  249: '𒄷𒋛',
#  250: '𒆜',
#  251: '𒑅',
#  252: '𒌓𒅗𒁇',
#  253: '𒍚',
#  254: '𒄣',
#  255: '𒄢',
#  256: '𒀸𒀸',
#  257: '𒉺𒋼𒋛',
#  258: '𒇇',
#  259: '𒇻<OTHER>',
#  260: '𒃵',
#  261: '𒂅',
#  262: '𒉽𒉽',
#  263: '𒐛',
#  264: '𒊩𒆪',
#  265: '𒉎',
#  266: '𒋤',
#  267: '𒀹',
#  268: '𒁡',
#  269: '𒋺',
#  270: '𒌣',
#  271: '𒊨',
#  272: '𒊻',
#  273: '𒅋',
#  274: '𒅴',
#  275: '𒈮',
#  276: '𒃠',
#  277: '𒋗𒃻𒌉𒇲',
#  278: '𒁽',
#  279: '𒉈𒊒',
#  280: '𒆃',
#  281: '𒂔',
#  282: '𒉺𒀠',
#  283: '𒇴',
#  284: '𒐴',
#  285: '𒈭',
#  286: '𒋝',
#  287: '𒄒',
#  288: '𒐝',
#  289: '𒃰',
#  290: '𒍫',
#  291: '𒆹',
#  292: '𒊍',
#  293: '𒐇',
#  294: '𒌁',
#  295: '𒋡𒋗𒃮',
#  296: '𒅀',
#  297: '𒈲',
#  298: '𒆒',
#  299: '𒌔',
#  300: '𒊌',
#  301: '𒉄',
#  302: '𒁖',
#  303: '𒃲𒁔',
#  304: '𒉺𒌆',
#  305: '𒅘',
#  306: '𒄑𒈪',
#  307: '𒌉𒍑',
#  308: '𒂇',
#  309: '𒌓𒌓',
#  310: '𒇯𒁺',
#  311: '𒉻𒀭𒈹',
#  312: '𒁉𒌑𒊓',
#  313: '𒆸𒆸',
#  314: '𒄙',
#  315: '𒆯',
#  316: '𒉋',
#  317: '𒅗𒁲',
#  318: '𒆦',
#  319: '𒄑<OTHER>',
#  320: '𒐧',
#  321: '𒐡',
#  322: '𒈢',
#  323: '𒁱',
#  324: '𒋓𒄄',
#  325: '𒅆𒁾',
#  326: '𒁃',
#  327: '𒂕',
#  328: '𒂶',
#  329: '𒉠',
#  330: '𒍜',
#  331: '𒇋',
#  332: '𒊊',
#  333: '𒄋',
#  334: '𒃾',
#  335: '𒈖',
#  336: '𒋭',
#  337: '𒇬',
#  338: '𒆍',
#  339: '𒉪',
#  340: '𒁷',
#  341: '𒈪𒉭',
#  342: '𒋢𒆳𒊒',
#  343: '𒀀𒋗𒉀',
#  344: '𒋙',
#  345: '𒆲',
#  346: '𒇺',
#  347: '𒋒',
#  348: '𒉺<OTHER>𒁺',
#  349: '𒄘𒃼',
#  350: '𒌓𒄒𒉣',
#  351: '𒀖𒆪',
#  352: '𒈹𒍝',
#  353: '𒐠',
#  354: '𒀲𒅆𒂠',
#  355: '𒂈',
#  356: '𒁳',
#  357: '𒁺𒁺',
#  358: '𒆧',
#  359: '𒉇',
#  360: '𒅊',
#  361: '𒄬',
#  362: '𒋖',
#  363: '𒆠𒁉',
#  364: '𒐢',
#  365: '𒋼𒀕',
#  366: '𒄤',
#  367: '𒍇',
#  368: '𒍂',
#  369: '𒌵',
#  370: '𒇉',
#  371: '𒌓𒉣',
#  372: '𒀀𒑘𒉪',
#  373: '𒀭𒉀',
#  374: '𒃴',
#  375: '𒌋𒅗',
#  376: '𒊩𒃢',
#  377: '𒄑𒉋',
#  378: '𒄭𒄊',
#  379: '𒁰',
#  380: '𒉒',
#  381: '𒄴𒈨',
#  382: '𒆏',
#  383: '𒑙',
#  384: '𒌴',
#  385: '𒂞',
#  386: '𒈹𒂞',
#  387: '𒍩𒀭',
#  388: '𒇀',
#  389: '𒈯',
#  390: '𒆮',
#  391: '𒈨𒌍',
#  392: '𒁆',
#  393: '𒁆𒈜',
#  394: '𒂉',
#  395: '𒅲',
#  396: '𒀞',
#  397: '𒀀𒆗',
#  398: '𒌃',
#  399: '𒇻𒋢',
#  400: '𒇧',
#  401: '𒀭𒀹𒀭',
#  402: '𒉼',
#  403: '𒉀',
#  404: '<OTHER>𒋤',
#  405: '𒆜𒆳',
#  406: '𒐩',
#  407: '𒐑',
#  408: '𒀚',
#  409: '𒆠𒌓',
#  410: '𒋀𒀕',
#  411: '𒆠𒋢𒇻𒂠𒃻',
#  412: '𒑘𒑘𒉪',
#  413: '𒐣',
#  414: '𒁦',
#  415: '𒉽𒂊',
#  416: '𒊿',
#  417: '𒊾',
#  418: '𒉭',
#  419: '𒍎',
#  420: '𒇭',
#  421: '𒉌𒄑',
#  422: '𒑂',
#  423: '𒀲𒀴',
#  424: '𒁻',
#  425: '𒐶',
#  426: '𒐫',
#  427: '𒁔',
#  428: '𒌙',
#  429: '𒉣𒇬',
#  430: '𒋢𒀀',
#  431: '𒄦',
#  432: '𒍍',
#  433: '𒉣𒈨',
#  434: '𒃲𒌺',
#  435: '𒃲𒋼',
#  436: '𒃸',
#  437: '𒂗𒈨𒇷',
#  438: '𒀀𒌅𒃮𒇺',
#  439: '𒀀𒄩',
#  440: '𒁼',
#  441: '𒀩',
#  442: '𒍤𒆸',
#  443: '𒀏',
#  444: '𒄯𒄯',
#  445: '𒄑𒌆𒉿',
#  446: '𒄛',
#  447: '𒑘𒉀',
#  448: '𒌓𒀕',
#  449: '𒅆𒂠',
#  450: '𒍝𒈹'}

# %%
def convert_bbox(bbox, img_width, img_height):
    x_min, y_min, x_max, y_max = bbox
    x_center = (x_min + x_max) / 2.0 / img_width
    y_center = (y_min + y_max) / 2.0 / img_height
    width    = (x_max - x_min) / img_width
    height   = (y_max - y_min) / img_height
    return x_center, y_center, width, height

# %%
from PIL import Image
from tqdm import tqdm
def process_json(json_file, img_output_dir, lbl_output_dir, label_key):
    with open(json_file, "r", encoding="utf-8") as f:
        data = json.load(f)

    for key, item in tqdm(data.items(), desc="Processing items"):
        # get image path
        img_path = os.path.join(IMAGES_DIR, os.path.basename(item['image_path']))
        if not os.path.exists(img_path):
            print(f"Warning: {img_path} does not exist.")
            continue
        
        # copy image
        dst_img_path = os.path.join(img_output_dir, os.path.basename(img_path))
        shutil.copy(img_path, dst_img_path)

        # open image to get size
        with Image.open(img_path) as img:
            w, h = img.size
        
        # write label file
        label_file = os.path.splitext(os.path.basename(img_path))[0] + ".txt"
        label_file_path = os.path.join(lbl_output_dir, label_file)
        
        with open(label_file_path, "w", encoding="utf-8") as f:
            for bbox_entry in item['bboxes']:
                if label_key == "is_sign":
                    class_id = 0
                elif label_key == "charname":
                    class_id = bbox_entry['charname_id']
                elif label_key == "transliteration":
                    class_id = bbox_entry['transliteration_id']
                elif label_key == "charname_topN":
                    class_id = bbox_entry['charname_id']
                    if class_id >= N:
                        class_id = N  # group together
                elif label_key == "unicode":
                    class_id = bbox_entry['unicode_id']
                    
                elif label_key == "unicode_topN":
                    class_id = bbox_entry['unicode_id']
                    if class_id >= N:
                        class_id = N  # group together
                    
                else:
                    raise ValueError("label_key must be one of ['is_sign','charname','transliteration','charname_topN','unicode','unicode_topN']")
                    
                
                x_center, y_center, width, height = convert_bbox(bbox_entry['bbox'], w, h)
                f.write(f"{class_id} {x_center:.6f} {y_center:.6f} {width:.6f} {height:.6f}\n")
        unicode_string = item["unicode_string"]
        # save at whole_image_unicode/{train,val}/, have a .txt file with the full unicode string.
        split = "train" if "train" in json_file else "val"
        unicode_output_dir = os.path.join(OUTPUT_DIR, "3_YOLO_ultra/whole_image_unicode", split)
        os.makedirs(unicode_output_dir, exist_ok=True)
        unicode_file_path = os.path.join(unicode_output_dir, os.path.splitext(os.path.basename(img_path))[0] + ".txt")
        with open(unicode_file_path, "w", encoding="utf-8") as uf:
            uf.write(unicode_string)

# ----------------- PROCESS DATA -----------------
print("Processing training data...")
process_json(TRAIN_JSON, IMG_TRAIN_DIR, LBL_TRAIN_DIR, label_key)

print("Processing validation data...")
process_json(VAL_JSON, IMG_VAL_DIR, LBL_VAL_DIR, label_key)

print("Done! YOLO dataset ready.")
# Out:
# Processing training data...
# Processing items: 100%|██████████| 856/856 [00:14<00:00, 60.79it/s]
# Processing validation data...
# Processing items: 100%|██████████| 214/214 [00:03<00:00, 67.37it/s]
# Done! YOLO dataset ready.

# %%
import yaml
yaml_data = {
    'path': OUTPUT_DIR,  # root dataset folder
    'train': 'images/train',
    'val': 'images/val',
    'nc':  None,  # number of classes, will fill automatically
    'names': None  # list of class names
}
if label_key == "is_sign":
    yaml_data['nc'] = 1
    yaml_data['names'] = ["sign"]
else:
    # collect all ids from all json
    import json
    train_json = os.path.join("../MaiCuBeDa/all_photo_anno.json")
    with open(train_json, "r", encoding="utf-8") as f:
        data = json.load(f)
    
    class_ids = set()
    for item in data.values():
        for bbox_entry in item['bboxes']:
            if label_key == "charname":
                class_ids.add(bbox_entry['charname_id'])
            elif label_key == "transliteration":
                class_ids.add(bbox_entry['transliteration_id'])
            elif label_key == "charname_topN":
                cid = bbox_entry['charname_id']
                if cid >= N:
                    cid = N
                class_ids.add(cid)
            elif label_key == "unicode":
                class_ids.add(bbox_entry['unicode_id'])
            elif label_key == "unicode_topN":
                cid = bbox_entry['unicode_id']
                if cid >= N:
                    cid = N
                class_ids.add(cid)
    
    class_ids = sorted(list(class_ids))
    yaml_data['nc'] = len(class_ids)  # assuming class ids are 1-indexed
    yaml_data['names'] = [reverse_dict_id[i] for i in class_ids]

# ----------------- SAVE YAML -----------------
yaml_path = os.path.join(OUTPUT_DIR, "dataset.yaml")
with open(yaml_path, "w", encoding="utf-8") as f:
    yaml.dump(yaml_data, f,allow_unicode=True)

print(f"YOLO dataset.yaml saved to {yaml_path}")
# Out:
# YOLO dataset.yaml saved to D:/sumer/3_YOLO_ultra/dataset_unicode_topN\dataset.yaml

# %%
# clear cache at OUTPUT_DIR/labels/{train,val}.cache file
for split in ['train', 'val']:
    cache_dir = os.path.join(OUTPUT_DIR, "labels", split + ".cache")
    if os.path.exists(cache_dir):
        os.remove(cache_dir)
        print(f"Cleared cache file: {cache_dir}")
# Out:
# Cleared cache file: D:/sumer/3_YOLO_ultra/dataset_unicode_topN\labels\train.cache
# Cleared cache file: D:/sumer/3_YOLO_ultra/dataset_unicode_topN\labels\val.cache
